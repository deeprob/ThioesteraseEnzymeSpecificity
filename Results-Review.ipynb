# %%
import pandas as pd

# %% [markdown]
# # Feature Extraction Technique Comparison

# %%
feat_report_file = './data/results/indfeatreport.csv'
df_features = pd.read_csv(feat_report_file, index_col=0).sort_values('mean_accuracy', ascending=False)

# %%
df_features.loc[:,['mean_accuracy','mean_precision','mean_recall']]
# Out:
#                           mean_accuracy  mean_precision  mean_recall
# featname
# KSCTriad                           0.79            0.89         0.89
# CKSAAP                             0.79            0.89         0.87
# gaakmer                            0.79            0.85         0.85
# CTriad                             0.79            0.89         0.89
# DDE                                0.79            0.87         0.88
# spectrumKernel                     0.79            0.89         0.87
# gappyKernel                        0.79            0.89         0.87
# NMBroto                            0.78            0.89         0.87
# GTPC                               0.78            0.86         0.86
# kmer                               0.78            0.85         0.85
# CKSAAGP                            0.77            0.84         0.85
# rpm_pssm                           0.76            0.86         0.86
# ...

# %% [markdown]
# # Base Learner Assessment
#
# **Scores are given in the ipynb modelEvaluation present in notebook directory**

# %% [markdown]
# # Ensemble model performance

# %%
ensemble_model_file = './data/results/ensemble_results.csv'
df_en = pd.read_csv(ensemble_model_file, index_col=0)

# %%
df_en
# Out:
#           min_precision  max_precision  mean_precision  std_precision  \
# ensemble
# ensemble           0.44            1.0            0.89           0.09
#
#           min_recall  max_recall  mean_recall  std_recall  min_accuracy  \
# ensemble
# ensemble        0.56         1.0         0.91        0.08          0.59
#
#           max_accuracy  mean_accuracy  std_accuracy
# ensemble
# ensemble           1.0           0.83          0.06

# %%
df_features.head().loc[:,['mean_precision','min_precision','std_precision',
                         'mean_recall','min_recall','std_recall',
                         'mean_accuracy','min_accuracy','std_accuracy']]
# Out:
#           mean_precision  min_precision  std_precision  mean_recall  \
# featname
# KSCTriad            0.89           0.42           0.09         0.89
# CKSAAP              0.89           0.43           0.09         0.87
# gaakmer             0.85           0.40           0.10         0.85
# CTriad              0.89           0.42           0.09         0.89
# DDE                 0.87           0.40           0.09         0.88
#
#           min_recall  std_recall  mean_accuracy  min_accuracy  std_accuracy
# featname
# KSCTriad        0.47        0.09           0.79          0.48          0.07
# CKSAAP          0.38        0.10           0.79          0.48          0.07
# gaakmer         0.25        0.11           0.79          0.48          0.07
# CTriad          0.47        0.09           0.79          0.48          0.07
# DDE             0.38        0.09           0.79          0.48          0.07

# %% [markdown]
# ## Ensemble Model Histograms
